# %%
library('MASS')
# Out:
# Warning message:
# "package 'MASS' was built under R version 3.6.2"

# %%
#reading the dataset in R 

dataset<-read.csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
dataset
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio b
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3    396.90
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8    396.90
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8    392.83
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7    394.63
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7    396.90
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7    394.12
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    395.60
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    396.90
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    386.63
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    386.71
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    392.52
# ...

# %%
#ploting the dataset in corrleogram

plot(dataset)
# Out:
# plot without title

# %%
install.packages('corrplot')
# Out:
# Installing package into 'C:/Users/somy/Documents/R/win-library/3.6'
# (as 'lib' is unspecified)
# package 'corrplot' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\somy\AppData\Local\Temp\Rtmp6h31Tw\downloaded_packages

# %%
#infering the correlation 
cr<-cor(dataset)

corrplot::corrplot(cr,type='lower')
# Out:
# Plot with title ""

# %%
corrplot::corrplot(cr,method='number')
# Out:
# Plot with title ""

# %%
#divide the dataset into train and test
split=sample(2,nrow(dataset),prob = c(0.8,0.2),replace = T)

# %%
train<-dataset[split==1,]
test<-dataset[split==2,]

# %%
#creating our linear regression model with medv as independent vairable and others as dependent variable

model<-lm(medv~.,data=train)
#summary of the model 

summary(model)

# %%
#predicitng the test values 
pred<-predict(model,test)

# %%
#ploting the actual vs the predeicted data
plot(pred,type='l',lty=1.8,col='blue')
lines(test$medv,type='l',col='green')
# Out:
# plot without title

# %%
#ploting the actual vs the predeicted data
plot(pred,col='red')
points(test$medv,col='green')
# Out:
# plot without title

# %%
#we can clearly see that indus and age are not correlated with medv 
#THUS removing the same and recreating the model
model<-lm(medv~.-indus-age,data = train)

summary(model)
# Out:
# Call:
# lm(formula = medv ~ . - indus - age, data = train)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -10.5358  -2.8146  -0.7735   1.7213  26.6776
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  32.415290   5.746533   5.641 3.27e-08 ***
# crim         -0.114518   0.036919  -3.102  0.00206 **
# zn            0.041217   0.014851   2.775  0.00578 **
# chas          4.144791   0.923746   4.487 9.53e-06 ***
# nox         -16.778087   4.151815  -4.041 6.42e-05 ***
# rm            4.007877   0.469133   8.543 3.02e-16 ***
# dis          -1.389406   0.203120  -6.840 3.09e-11 ***
# rad           0.283686   0.069924   4.057 6.01e-05 ***
# tax          -0.010861   0.003591  -3.024  0.00266 **
# ptratio      -0.845491   0.141066  -5.994 4.69e-09 ***
# b             0.008462   0.002984   2.835  0.00482 **
# lstat        -0.517294   0.051469 -10.051  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# ...

# %%
#predicitng the test values 
pred<-predict(model,test)

# %%
#ploting the actual vs the predeicted data
plot(pred,type='l',lty=1.8,col='blue')
lines(test$medv,type='l',col='green')
# Out:
# plot without title

# %%
#ploting the actual vs the predeicted data
plot(pred,col='red')
points(test$medv,col='green')
# Out:
# plot without title
